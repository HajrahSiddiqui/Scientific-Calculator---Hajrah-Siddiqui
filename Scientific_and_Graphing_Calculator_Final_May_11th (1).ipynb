# %%
#importing libraries
import pandas as pd  #Library for csv
import matplotlib.pyplot as plt #import library for plotting graphs
import numpy as np #numpy
import math
import matplotlib.ticker as tck
import plotly.graph_objects as go

#intro
print("Welcome to the epic Scientific and Graphing Calculator!! ")

while True: #while true for break statements

  #introducing the option if user wants mathematical or graphing function to solve their problems
  option = input("Would you like to preform a mathematical task or a graphing task? (Enter mathematical or graphing)")
  print("")
  if option == "mathematical": #if statement for mathematical

      #prompting 2 numbers as per the rubric
      number1 = float(input("Enter your first number: "))
      number2 = float(input("Enter your second number: "))

      print("")

      #making a list of the options so that its neat and tidy, esentially the user has to pick a number from 1-8 to enter what option they want
      print("From the list of mathematical options, enter what calculation you would like to do: ")
      print("")
      print("1 = Area of rectangle (Length x Width)")
      print("2 = Area of triangle ((Base x Height) / 2)")
      print("3 = Area of square (Length x Length)")
      print("4 = Area of circle (pi * r**2)")
      print("")
      print("5 = addition of the two numbers (x + y)")
      print("6 = subtraction of the two numbers (x - y)")
      print("7 = muliplication of the two numbers (x * y)")
      print("8 = division of the two numbers (x / y)")

      print("")

      #entering what calculation they want to do, I put a invalid statement but program already catches it with the float
      #so the invalid statements basically useless at this point but its fine
      What_you_wanna_see_mathlol = float(input("Enter what calculation you want to do from the list above: "))
      #area of solving for triangle,rectangle,square, and circle
      if What_you_wanna_see_mathlol == 1: #rectange - I need to find length and width as the 2 numbers may not be
        number4 = float(input("What is the length of the shape (in cm) : "))
        print(number4)
        number5 = float(input("What is the width of the shape (in cm) : "))
        print(number5)
        answerOfRectangle = (number4*number5)
        print("Area of rectangle is", answerOfRectangle, "cm^2")
        break #i put break for every if statement so that it doesn't continue

      elif What_you_wanna_see_mathlol == 2: #I do 2 instead of "2" because i need to compare it with a float not a string
        number9 = float(input("What is the base of the shape (in cm) : "))
        print(number9)
        number8 = float(input("What is the height of the shape (in cm) : "))
        print(number8)
        AnswerOfTriangle = ((number9*number8)/2)
        print("Area of triangle is", AnswerOfTriangle, "cm^2")
        break

      #The rest of the if statements I followed the same method of caluclating and stuff
      elif What_you_wanna_see_mathlol == 3:
        number3 = float(input("What is the length of the shape (in cm) : "))
        print(number3)
        answerOfSquare = math.pow(number3, 2)
        print("Area of square is", answerOfSquare, "cm^2")
        break

      elif What_you_wanna_see_mathlol == 4:
        radias = float(input("What is the radius of the circle (in cm) : "))
        print(radias)
        answerOfCircle = (radias ** 2) * math.pi
        print("Area of circle is", answerOfCircle, "cm^2")
        break

      #my now multiplication, addition, subtraiction, divison operations
      elif What_you_wanna_see_mathlol == 5:
        addition = (number2 + number1)
        print (addition)
        break

      elif What_you_wanna_see_mathlol == 6:
        subtraction = (number2 - number1)
        print (subtraction)
        break

      elif What_you_wanna_see_mathlol == 7:
        multiplication = (number2*number1)
        print (multiplication)
        break

      elif What_you_wanna_see_mathlol == 8:
        division = (number2/number1)
        print (division)
        break

      else:  #this is the invalid statement if user doesnt enter 1-8 number
        print("Invalid, restart")
        break

  elif option == "graphing":  #this is if the user selects graphing
    questionForGraphing = input("Would you like to display a polynomial graph or a trignometric graph? (Enter poly/trig)")   #this is for polynomial or trig graph whatever they want

    if questionForGraphing == "poly": #for poly
        equation = input("Please enter your polynomial function using x as the variable so for instance (3*x**2 + 4*x + 6): ")

        checkingForDigitsForPoly = equation.isdigit()  #this is so that they can check if there are onyl numbers in the equation - I want to ensure there
                                                      #ensure there are no errors and stuff so I have that

        if ("x" not in equation) and (equation != checkingForDigitsForPoly): #this is so that it knows that x must be in the equation as well the numbers
                                                                            #I did like not equal to meaning that if the equation answer does not have an x in it and is not all numbers it will be invalid input
          print("Restart the program please. invalid")
          break

        LinearIntersection = input("Would you like to have a linear intersection in your graph? (Yes or No)")  #this is the intersection part, users can also do a quadratic intersection or any other type
                                                                                                              #I programmed it so it can accomodate all intersections

        if LinearIntersection == "Yes":  #this is if the user says yes
              equation2 = input("Please enter your linear function using x as the variable so for instance (3*x + 6): ")  #this is the same instance like inputting the equation above

              #Same idea of checking for the equationa dn seeing if it is formatted right
              checkingForDigits1 = equation.isdigit()  #same as poly for checking if invalid or not
              checkingForDigits2 = equation2.isdigit()
              x1 = np.linspace(-10, 10, 400) #this is for the graph - linespace is the function to set the scale of the x axis, so it goes (start, finish, how many units it jumps until)
                                              #so here the x axis go from -10 to 10 and then goes 400 units each time it does a new unit
              x_linear = np.linspace(-10, 10, 400)

              #Checking for proper format for linear
              if ("x" not in equation) and (equation != checkingForDigits2):
                print("Restart the program please. invalid")
                break

              if ("x" not in equation2) and (equation2 != checkingForDigits2):
                print("Restart the program please. invalid")
                break

              #https://www.toppr.com/guides/python-guide/references/methods-and-functions/methods/built-in/eval/python-eval/#:~:text=Python%20eval()%20function%20is,the%20value%20as%20an%20integer.
              #try except is basically just like a block of code that checks if there is any syntax error or anything
              #Bascially the way I understand it is that try means that it tests a block of code for errors- got that from google,
              #Essentially because we are dealing with complicated equations here it must recheck everything for syntax and stuff before actually presenting data on the graph
              #The reason why is so that in our grpah there won't be any mistakes, because equations have so many symbols like the addition, mulitplication, and in programming there are symbols for that it needs to check which are applicable
              try:
                #https://stackoverflow.com/questions/2262333/is-there-a-built-in-or-more-pythonic-way-to-try-to-parse-a-string-to-an-integer

                #This whole line of code below me I got this from the sight toppr and prepbytes - i got the logic from toppr and prepbytes I found
                #The same scenario I was in when plotting
                #basically eval means getting an input as a string and outputting it as an integer (btw my code works for decimals to)
                # The reason I have to do eval is because - this is one of the big problems I ran into earlier, esnetially because x is in the equation when the question asks
                #"enter your equation, and you need to put in x as the variable" you can't put a string and a number together on the same line if you want the number actually to be added or do whatever math equaiton you want
                #so it becomes a string - thats why we do eval so that it turns the numbers which were strings into integers so that its easy to plot
                #It basically evaluates thenumbers being changed

                #the reason I do the {'x': x} is bascially because eval is to evaluate the exquation, it must evaluate x which is our x axis so it can fit
                #the parameters of the equaiton when plotting, what I mena by that is that it sees if also its efficient to. X is used as a global variable
                #that is basically likea variable declared outside the function, in this case our x is our global variable because it allows the x to be accepted into the equation as an expression
                      y1 = eval(equation, {'x': x1})   #doing the parsing with eval
                      y_linear = eval(equation2, {'x': x_linear} )

                      plt.plot(x_linear, y_linear)
                      plt.plot(x1, y1)
                      plt.title(" graph of " + equation + " and " + equation2)
                      plt.xlabel("X-Axis")
                      plt.ylabel("Y-Axis")
                      plt.grid(True)
                      plt.show()

              #As I mentioned in the eval line, because try is looking for any syntax and symbols, and since we have that eval there,-
              #the computer does not have an idea that x is needed as to be treated like a string since this is an expression so this line here allows basically
              #the x to be accepted thats why it says if anything other than x then please restart
              #because I already made an if statement about if x is not included this hsould not appear
              #The if statement above was for only the question's answer, this is now involved in the syntaxing and stuff so that even if the user accidentally uses something else than x it catches it
              #however the if statement I made is quite bulletproof so it will catch anything but still i included this
              #I got this from the sites above  bascailly a little form each
              except ValueError as x: #This is like the if statmeent got the as x_value from simply noting that value Error means the input is wrong
                                      #its wrong in the sense that it doesn't match the data type
                      print("Error. Please restart program")

        if LinearIntersection == "No":  #this is basically if the user says no i dont want a intersection it prints out the normal graph
          checkingForDigits = equation.isdigit()

          #following the same methods as above
          if "x" not in equation and equation != checkingForDigits:
            print("Restart the program please. invalid")
            break

          x1 = np.linspace(-10, 10, 400)

          try:
            y1 = eval(equation, {'x': x1})

            plt.plot(x1, y1)
            plt.title(" " + equation)
            plt.xlabel("X-Axis")
            plt.ylabel("Y-Axis")
            plt.grid(True)
            plt.show()

          except ValueError as x:
            print("Invalid")

        else:
          print("Invalid")
          break

    elif questionForGraphing == "trig":
        questionTrig = input("What graph would you like to be displayed on the graph: (cos, sin, or tan)")
        if questionTrig == "cos":

          #scrap work + comments on how I got to the code below for cos - I used a very helpful site which I have refered to below
           # x_axis = np.arange(0, 6 * np.pi, 0.1) #the np. arrange is basically just essentially np. array which is litterly just making evenly spaces between the x-axis points
                                                # essentially what this is is making evenly spaced out spaces so that my sin graph will come out even when being plot

                                                #the reason I do 6 is because basically its when the sine function stops so when it is reaching 6 * pi it stops
                                                #i can do any number I like but 6 is fine too

                                                #the 0.1 represents how it goes on a step of 0.1 everytime it moves, basically everytime it is plotted
                                                #this can also be changed

                                                #https://pythonforundergradengineers.com/plotting-sin-cos-with-matplotlib.html I got my logic from here =

          #these comments logics all will be replicated in the ambitious question I will do after I plot this

          #https://stackoverflow.com/questions/40642061/how-to-set-axis-ticks-in-multiples-of-pi-python-matplotlib
          # THIS IS FOR THE PIE AXIS

          #Line below I used from them
        # f, ax = plt.subplots(figsize = (10,5))  #will explain all of this in readme function

          #This one I already knew how to do these two ones because I did them above as u can see but instead I  also included...
          # I did -5 * np.pi because what was different from the first one and this one starts at -5, that one started at 0
        # x_axis = np.linspace(-5 * np.pi, 5 * np. pi, 1001)
          #y_axis = np.cos(x_axis)
          #ax.plot(x_axis / np.pi, y_axis)
          #ax.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
          #ax.xaxis.set_major_locator(tck.MultipleLocator(base=1.0))



          #plt.style.use("ggplot")
          #plt.title("Sine Function")
          #plt.xlabel("X axis")
          #plt.ylabel("Y axis")
          #plt.show()

              questionForWtvGraph1 = input("Would you like to import your own equation or see the cos function itself? (equation or itself): ")

              if questionForWtvGraph1 == "equation":    #https://datacrayon.com/signal-processing/sine-waves-in-the-time-domain/ - used this site
              #sin function equation - using that as refrence to plot it
                A_value1 = float(input("Enter your A value, your amplitude: "))
                B_value1 = float(input("Enter your B value, your frequency: "))
                C_value1 = float(input("Enter your C value, your horizontal shift: "))
                D_value1 = float(input("Enter your D value, your vertical shift: "))
                range_Start_Value1 = int(input("Enter what number you would like for your graph to start at (starting at this point)"))
                range_Stop_Value1 = int(input("Enter what number you would like to go up till on your graph: (stopping at that point) "))

                sample_rate1 = 1000
                x_axis1 = np.arange(range_Start_Value1, range_Stop_Value1, 1/sample_rate1)
                print(x_axis1)
                CosineWave1 = A_value1 * np.cos(2 * np.pi * B_value1 * x_axis1 + D_value1)
                print(CosineWave1)
                fig = go.Figure(layout=dict(xaxis=dict(title='X axis'),yaxis=dict(title='Y axis')))
                fig.add_scatter(x=x_axis1, y=CosineWave1)
                plt.grid(True)
                fig.show()

              if questionForWtvGraph1 == "itself":
                f, ax = plt.subplots(figsize = (10,5))
                x_axis2 = np.linspace(-5 * np.pi, 5 * np. pi, 1001)
                y_axis2 = np.cos(x_axis2)

                ax.plot(x_axis2 / np.pi, y_axis2)

                ax.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
                ax.xaxis.set_major_locator(tck.MultipleLocator(base=1.0))
                plt.style.use("ggplot")
                plt.title("Cosine Function")
                plt.xlabel("X axis")
                plt.ylabel("Y axis")
                plt.grid(True)
                plt.show()

              if questionForWtvGraph1 != "itself" and "equation":
                print("Invalid input.")
                break

        elif questionTrig == "sin":

              questionForWtvGraph2 = input("Would you like to import your own equation or see the cos function itself? (equation or itself): ")

              if questionForWtvGraph2 == "equation":
                A_value2 = float(input("Enter your A value, your amplitude: "))
                B_value2 = float(input("Enter your B value, your frequency: "))
                C_value2 = float(input("Enter your C value, your horizontal shift: "))
                D_value2 = float(input("Enter your D value, your vertical shift: "))
                range_Start_Value2 = int(input("Enter what number you would like for your graph to start at (starting at this point)"))
                range_Stop_Value2 = int(input("Enter what number you would like to go up till on your graph: (stopping at that point) "))

                #https://datacrayon.com/signal-processing/sine-waves-in-the-time-domain/ - used this site
                sample_rate2 = 1000
                x_axis_forSin = np.arange(range_Start_Value2, range_Stop_Value2, 1/sample_rate2)
                print(x_axis_forSin)
                sinewave2 = A_value2 * np.sin(2 * np.pi * B_value2 * x_axis_forSin + D_value2)
                print(sinewave2)
                fig = go.Figure(layout=dict(xaxis=dict(title='X axis'),yaxis=dict(title='Y axis')))
                fig.add_scatter(x=x_axis_forSin, y=sinewave2)
                plt.grid(True)
                fig.show()

          #scrap work before I got to answer above
          # x_axis = np.linspace(range_Start_Value * np.pi, range_Stop_Value * np. pi, 1001)

          #  sample_rate = 1000
          # Values = np.arange(range_Start_Value, range_Stop_Value, 1000/sample_rate)
            #print(sample_rate)

            #mathPortion = A_value * np.sin(((B_value * Values) + C_value) + D_value)
            #print(mathPortion)

            #fig = go.Figure(layout=dict(xaxis=dict(title='X axis'),yaxis=dict(title='Y axis')))
            #plt.plot(Values, mathPortion)
            #plt.show()

            #ax.plot(x / np.pi, y)
            #ax.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
            #ax.xaxis.set_major_locator(tck.MultipleLocator(base=1.0))

            #plt.style.use("ggplot")

            #plt.plot(x, y)
            #plt.xlabel("X axis")
            #plt.ylabel("Y axis")
            #plt.show()

              if questionForWtvGraph2 == "itself":
                f, ax = plt.subplots(figsize = (10,5))
                x_axis4 = np.linspace(-5 * np.pi, 5 * np. pi, 1001)
                y_axis4 = np.sin(x_axis4)

                ax.plot(x_axis4 / np.pi, y_axis4)

                ax.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
                ax.xaxis.set_major_locator(tck.MultipleLocator(base=1.0))
                plt.style.use("ggplot")
                plt.title("Sine Function")
                plt.xlabel("X axis")
                plt.ylabel("Y axis")
                plt.grid(True)
                plt.show()

              if questionForWtvGraph2 != "itself" and "equation":
                print("Invalid input.")
                break

        elif questionTrig == "tan":

            questionForWtvGraph3 = input("Would you like to import your own equation or see the tan function itself? (equation or itself): ")

            if questionForWtvGraph3 == "equation":
                A_value3 = float(input("Enter your A value, your amplitude: "))
                B_value3 = float(input("Enter your B value, your frequency: "))
                C_value3 = float(input("Enter your C value, your horizontal shift: "))
                D_value3 = float(input("Enter your D value, your vertical shift: "))
                range_Start_Value3 = int(input("Enter what number you would like for your graph to start at (starting at this point)"))
                range_Stop_Value3 = int(input("Enter what number you would like to go up till on your graph: (stopping at that point) "))

                x = np.linspace(-2 * math.pi, 2 * math.pi, 400)
                y = A_value3 * np.tan(B_value3 * (x + C_value3)) + D_value3
                y[:-1][np.diff(y) < 0] = np.nan     #so basically for the tan I switched up the entire thing because when I first submitted the assignment my tan was wrong (you still gave me the mark because)
                                                    #My cos and sin were right but basically I fixed tan, so essentially its litterly just plotting a normal graph but I used x as linespace
                                                    #and using that for every point it went every 400 it would produce a y
                                                    #basically that made sense but what was the real game changer was the y[:-1][np.diff(y) < 0] = np.nan
                                                    #so what y[:-1][np.diff(y) < 0] = np.nan is basically is that [:-1] erases the last end of the array which is useful because
                                                    #in the tan function that is how it plays out
                                                    #The np.diff(y) basically si that np.diff is to find the discrete difference for all the values basically it finds every difference of the consecutive elements
                                                    #the reason why it is <0 is so that it can make a bool where it checks which points are negative or not
                                                    #the nan is basically meaning that all of the statmeent is not a number so essentially the hwole reason on why we are incorperating tan into this is because if there is missing data it helps replace it essnetilaly
                plt.grid(True)
                plt.xlabel("x-axis")
                plt.ylabel("y-axis")
                plt.ylim(-10,10)
                plt.title("y = tan(x)", fontsize=14)
                plt.plot(x, y)
                plt.show()

            if questionForWtvGraph3 == "itself": #https://www.physicsforums.com/threads/graph-tan-and-arctan-with-python.986828/#:~:text=How%20do%20I%20plot%20a,the%20colors%20and%20line%20styles.
              x = np.linspace(-2 * math.pi, 2 * math.pi, 1000)
              y = np.tan(x)
              #https://gist.github.com/ryanorsinger/b62042c8b12ca74dd3bdc27fa7291401
              y[:-1][np.diff(y) < 0] = np.nan # I just used just this line from the github guy, I know it looks like our codes are identical but I didn;t copy paste I promise I had this before tis just this specific line helped make it true
              plt.grid(True)
              plt.xlabel("x-axis")
              plt.ylabel("y-axis")
              plt.ylim(-10,10)
              plt.xlim(-2 * math.pi, 2 * math.pi)
              plt.title("y = tan(x)", fontsize=14)
              plt.plot(x, y)
              plt.show()


          #Scrap work...
            #https://datacrayon.com/signal-processing/sine-waves-in-the-time-domain/ - used this site
          #  sample_rate3 = 1000
          #  x_axis_fortan = np.arange(range_Start_Value3, range_Stop_Value3, 1/sample_rate3)
           # print(x_axis_fortan)
           #tanwave3 = A_value3 * np.tan(2 * np.pi * B_value3 * x_axis_fortan + D_value3)
           ## print(tanwave3)

            #fig = go.Figure(layout=dict(xaxis=dict(title='X axis'),yaxis=dict(title='Y axis')))
            #fig.add_scatter(x=x_axis_fortan, y=tanwave3)
            #fig.show()

#all of these down here are invalid input statements if the user says anything wrong in anything
            if questionForWtvGraph3 != "itself" and "equation": #invalid statement for tan
                print("Invalid input.")
                break

        else: #invalid statement for if the user does not put sin cos or tan
            print("Invalid Input.")
            break
    else: #invalid statement if it does not say poly or trig
      print("Invalid Input.")
      break

  else: #invalid statmeent if does not enter graphing or mathematicl
    print("Invalid input. ")
    break
# Out:
# Welcome to the epic Scientific and Graphing Calculator!!
